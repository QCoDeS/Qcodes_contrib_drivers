# %%
from qcodes_contrib_drivers.drivers.Pico.Pico_PST import PicoPST
pico = PicoPST('pico', 'USB0::0x1209::0x4000::E660583883555B31::INSTR')
pico.gp22(40)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from qcodes_contrib_drivers.drivers.Pico.Pico_PST import PicoPST
#       2 pico = PicoPST('pico', 'USB0::0x1209::0x4000::E660583883555B31::INSTR')
#       3 pico.gp22(40)
#
# File /Volumes/git/git/qcodes/Qcodes_contrib_drivers/src/qcodes_contrib_drivers/__init__.py:2
# ----> 2 from ._version import __version__
#
# File /Volumes/git/git/qcodes/Qcodes_contrib_drivers/src/qcodes_contrib_drivers/_version.py:12
#       8     path = Path(qcodes_contrib_drivers.__file__).parent
#       9     return versioningit.get_version(project_dir=path.parent.parent)
# ---> 12 __version__ = _get_version()
#
# File /Volumes/git/git/qcodes/Qcodes_contrib_drivers/src/qcodes_contrib_drivers/_version.py:4, in _get_version()
#       1 def _get_version() -> str:
#       2     from pathlib import Path
# ----> 4     import versioningit
#       6     import qcodes_contrib_drivers
#       8     path = Path(qcodes_contrib_drivers.__file__).parent
#
# ModuleNotFoundError: No module named 'versioningit'
