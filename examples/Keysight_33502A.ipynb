# %% [markdown]
# # Example with the Keysight 33502A isolated amplifier

# %% [markdown]
# ### Import

# %%
from qcodes_contrib_drivers.drivers.Keysight.Keysight_33502A import Keysight33502A

# %% [markdown]
# ### Connection

# %%
driver = Keysight33502A(
    'Keysight_33502A',
    address='USB0::0x0957::0x2207::MY59000417::INSTR', # Change with sim or device address to run 
)
# Out:
# Connected to: Agilent Technologies 33502A (serial:MY59000417, firmware:02.02-1924.2841-3.16-BD.4-1.00) in 0.15s

# %% [markdown]
# ### Usage

# %%
driver.ch1.coupling()
# Out:
# 'DC'

# %%
driver.ch1.impedance()
# Out:
# 1000000.0

# %%
driver.ch1.path()
# Out:
# 'DIR'

# %%
driver.ch1.state()
# Out:
# 'OFF'

# %%
driver.ch1.impedance(50)
driver.ch1.impedance()
# Out:
# 50.0

# %%
driver.ch1.state('ON')
driver.ch1.state()
# Out:
# 'ON'

# %%
driver.ch1.state('OFF')
driver.ch1.impedance(1000000)
driver.close()
